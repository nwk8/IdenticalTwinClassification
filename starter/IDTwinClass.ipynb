# %% [markdown]
# # Twin Image Classifier Project / Notes
# **Goal:** Build a simple machine learning classifier that can tell the difference between
# me and my identical twin using basic ML concepts (no deep learning).
#
# ## Step 1: Project Overview
# - **Type:** Classification
# - **Input:** Images of me and my twin
# - **Output:** “Me” or “Twin”
# - **Algorithms:** Decision Tree, Logistic Regression, KNN (try a few)
# - **Evaluation Metric:** Accuracy
